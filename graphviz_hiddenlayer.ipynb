# %%
from yolov1 import yolonet
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = yolonet()
net = net.to(device)

# %%
import hiddenlayer as hl
input_cuda = torch.zeros([1, 3, 448, 448]).to(device)
hl.build_graph(net, input_cuda)
